# %%
#NYC sale prices from 2017 to 2023, needs graphs(hvplot/geoviews)
#needs analysis questions, what is the overall trend of the data?
#calculate max/min prices
#calculate percentage change?
#compare sale prices with CHI and LA
#analysis of pre and post pandemic (split dataframe into two for one pre and one for post pandemic

# %%
from pathlib import Path
import pandas as pd
import hvplot.pandas as hvplot

# %%
# Import csv file using pathlib, and verify the file exists (Verification
#method is written in markdown)

file_path = Path(r"C:\Users\ppate\fintech-boot-camp\Project-01\
Metro_median_sale_price_uc_sfrcondo_sm_month_2017-2023.csv")

# if file_path.exists():
#    print("File exists!")

# %%
# Created a dataframe of the median sale prices of U.S major cities, from 2017 
#to 2023 using pandas. Displayed the first and last five rows of the dataframe

us_cities_sale_price = pd.read_csv(file_path)
us_cities_sale_price
# Out:
#      RegionID  SizeRank                  RegionName RegionType StateName  \
# 0      102001         0               United States    country       NaN
# 1      394913         1                New York, NY        msa        NY
# 2      753899         2             Los Angeles, CA        msa        CA
# 3      394463         3                 Chicago, IL        msa        IL
# 4      394514         4                  Dallas, TX        msa        TX
# ..        ...       ...                         ...        ...       ...
# 573    395206       825  Washington Court House, OH        msa        OH
# 574    394864       833           Mineral Wells, TX        msa        TX
# 575    395159       848                  Toccoa, GA        msa        GA
# 576    753921       867       Steamboat Springs, CO        msa        CO
# 577    394718       892               Jamestown, ND        msa        ND
#
#      1/31/2017  2/28/2017  3/31/2017  4/30/2017  5/31/2017  ...  11/30/2022  \
# ...

# %%
# Switch rows and columns using the transpose function in pandas

#us_cities_sale_price_df= us_cities_sale_price.transpose()
#us_cities_sale_price_df

# %%
# Remove rows and columns to isolate data on New York City

dropped_rows = us_cities_sale_price_df.drop(["RegionID",
                                             "SizeRank",
                                             "RegionType",
                                            "StateName"],
                                            axis = 0)
#print(dropped_rows)

dropped_column_0 = dropped_rows.drop([0], axis = 1)
#print(dropped_column_0)

nyc_median_sale_price = dropped_column_0.drop(dropped_column_0.columns[1:577], axis = 1)
nyc_median_sale_price
# Out:
#                        1
# RegionName  New York, NY
# 1/31/2017       375000.0
# 2/28/2017       373333.0
# 3/31/2017       373333.0
# 4/30/2017       374333.0
# ...                  ...
# 4/30/2023       519667.0
# 5/31/2023       539667.0
# 6/30/2023       563000.0
# 7/31/2023       583333.0
# 8/31/2023         598333
#
# [81 rows x 1 columns]

# %%
print(nyc_median_sale_price.columns)
# Out:
# RangeIndex(start=1, stop=2, step=1)

# %%
nyc_median_sale_price.columns["0"] = pd.to_datetime(nyc_median_sale_price.columns["0"])
nyc_median_sale_price['Formatted_Date'] = df['Date'].dt.strftime('%Y')

nyc_median_sale_price
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 nyc_median_sale_price.columns["0"] = pd.to_datetime(nyc_median_sale_price.columns["0"])
#       2 nyc_median_sale_price['Formatted_Date'] = df['Date'].dt.strftime('%Y')
#       4 nyc_median_sale_price
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:972, in RangeIndex.__getitem__(self, key)
#     968         raise IndexError(
#     969             f"index {key} is out of bounds for axis 0 with size {len(self)}"
#     970         ) from err
#     971 elif is_scalar(key):
# --> 972     raise IndexError(
#     973         "only integers, slices (`:`), "
#     974         "ellipsis (`...`), numpy.newaxis (`None`) "
#     975         "and integer or boolean "
#     976         "arrays are valid indices"
#     977     )
#     978 # fall back to Int64Index
# ...

# %%
   nyc_arrests['ARREST_DATE'] = pd.to_datetime(nyc_arrests['ARREST_DATE'])
nyc_arrests['Year'] = nyc_arrests['ARREST_DATE'].dt.strftime('%Y')
#nyc_arrests
