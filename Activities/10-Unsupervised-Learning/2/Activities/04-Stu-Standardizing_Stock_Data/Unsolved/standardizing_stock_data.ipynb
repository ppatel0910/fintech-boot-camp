# %% [markdown]
# # Standardizing Stock Data
#
# In this activity, you’ll use the `StandardScaler` module and clustering optimization techniques to cluster stocks. The purpose of clustering the stocks will be to define a portfolio investment strategy.
#
# Instructions
#
# 1. Read in the `tsx-energy-2018.csv` file from the `Resources` folder and create the DataFrame. Make sure to set the `Ticker` column as the DataFrame’s index. Then review the DataFrame.
#
#     > **Note** The stock data that’s provided for this activity contains the yearly mean prices (open, high, low, and close), volume, annual return, and annual variance from companies in the energy sector that the TSX lists.
#
# 2. To prepare the data, use the `StandardScaler` module and the `fit_transform` function to scale all the columns containing numerical values. Review a five-row sample of the scaled data using bracket notation ([0:5]).
#
# 3. Create a new DataFrame called `df_stocks_scaled` that contains the scaled data. Make sure to do the following:
#
#     - Use the same labels that were referenced in the `StandardScaler` for the column names.
#     - Add a column to the DataFrame that consists of the tickers from the original DataFrame. (Hint: This column was the index).
#
#     - Set the new column of tickers as the index for the new DataFrame.
#
#     - Review the resulting DataFrame.
#
# 4. Encode the “EnergyType” column using `pd.get_dummies`, and save the result in a separate DataFrame called `df_oil_dummies`. Note that, because the company name isn’t relevant for clustering, you don’t need to encode the “CompanyName” column.
#
# 5. Using the `pd.concat` function, concatenate the `df_stocks_scaled` DataFrame with the `df_oil_dummies` DataFrame, along an axis value of 1 (`axis=1` tells Pandas to join the data horizontally by columns). Review the concatenated DataFrame.
#
# 6. Using the concatenated DataFrame, cluster the data by using the K-means algorithm and a k value of 3. Create a copy of the concatenated DataFrame, and add the resulting list of company segment values as a new column.
#
#
#
# References
#
# [scikit-learn StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html)
#
# [scikit-learn Preprocessing Data](https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing-scaler)
#
# [Pandas concat function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html)
#
# [scikit-learn Python Library](https://scikit-learn.org)

# %%
# Import the required libraries and dependencies
from pathlib import Path
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Step 1: Read in the `tsx-energy-2018.csv` file from the `Resources` folder and create the DataFrame. Make sure to set the `Ticker` column as the DataFrame’s index. Then review the DataFrame.

# %%
# Read the CSV file into a Pandas DataFrame
# Set the index using the Ticker column
file_path = Path("../Resources/tsx-energy-2018.csv")
df_stocks = pd.read_csv(file_path, 
                        index_col = "Ticker")
                        
# Review the DataFrame
df_stocks.head()
# Out:
#                                CompanyName  MeanOpen  MeanHigh  MeanLow  \
# Ticker
# ARX                     ARC Resources Ltd.     13.14     13.34    12.91
# CCO                     Cameco Corporation     13.70     13.92    13.50
# CNQ     Canadian Natural Resources Limited     41.97     42.46    41.46
# CVE                    Cenovus Energy Inc.     11.96     12.18    11.75
# CPG            Crescent Point Energy Corp.      8.53      8.67     8.36
#
#         MeanClose  MeanVolume  AnnualReturn  AnnualVariance    EnergyType
# Ticker
# ARX         13.10  1479913.38       -0.7275          0.3590           Oil
# CCO         13.70  1203788.22        0.2014          0.3693  Other Energy
# CNQ         41.91  3218248.68       -0.3461          0.2947           Oil
# CVE         11.95  4566143.56       -0.3219          0.4500           Oil
# CPG          8.50  3919414.03       -1.0103          0.4597  Other Energy

# %% [markdown]
# ## Step 2: To prepare the data, use the `StandardScaler` module and the `fit_transform` function to scale all the columns containing numerical values. Review a five row sample of the scaled data using bracket notation ([0:5]). Create a dataframe containing the scaled data.

# %%
# Use the StandardScaler module and fit_transform function to 
# scale all columns with numerical values
stock_data_scaled = StandardScaler().fit_transform(df_stocks
    [["MeanOpen", 
    "MeanHigh", 
    "MeanLow",
    "MeanVolume", 
    "AnnualReturn",
    "AnnualVariance"]])

# Diplay the first five rows of the scaled data
#stock_data_scaled[0:5]

# Create a DataFrame called with the scaled data
df_stocks_scaled = pd.DataFrame(stock_data_scaled)
stocks_scaled = df_stocks_scaled.rename(columns = {0 : "MeanOpen", 
                                                   1 : "MeanHigh",
                                                   2 : "MeanLow",
                                                   3 : "MeanVolume",
                                                   4 : "AnnualReturn",
                                                   5 : "AnnualVariance"})
stocks_scaled
# Out:
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
#     MeanOpen  MeanHigh   MeanLow  MeanVolume  AnnualReturn  AnnualVariance
# 0  -0.916832 -0.917217 -0.918045   -0.152786     -1.332445        0.460854
# 1  -0.880152 -0.879472 -0.879062   -0.379117      1.695742        0.559411
# 2   0.971524  0.977848  0.968315    1.272074     -0.089092       -0.154415
# 3  -0.994122 -0.992707 -0.994689    2.376902     -0.010201        1.331607
# 4  -1.218785 -1.221130 -1.218673    1.846798     -2.254365        1.424424
# 5   1.067154  1.064401  1.063459    1.720226      0.389472       -0.736194
# 6  -0.817272 -0.815696 -0.817615   -0.453229      0.206587        0.533576
# 7  -0.563789 -0.566448 -0.559934   -1.073401      0.950187       -0.552474
# 8  -0.540209 -0.539766 -0.539452   -0.281932      0.094118        0.006339
# 9   0.826770  0.829470  0.829563   -0.483906      0.571378       -0.855803
# 10 -0.246115 -0.252773 -0.243448   -0.432973     -0.034325       -1.025169
# 11  0.464557  0.461781  0.464184   -0.920633     -0.237095       -0.790735
# 12 -1.267255 -1.267335 -1.268227    0.387923      1.683028        2.769786
# 13 -0.806137 -0.809839 -0.803079   -1.265295     -0.029109       -0.783080
# 14 -0.460954 -0.455816 -0.465451   -0.845754      0.304060        0.929721
# 15  0.478966  0.483257  0.482024   -1.034973      1.644887       -0.508458
# 16  1.078289  1.074163  1.082620   -0.337238      0.593546       -1.177312
# 17 -0.122976 -0.120665 -0.123858   -0.938063     -1.240188       -0.426167
# 18 -0.787142 -0.783807 -0.791847   -0.433758     -1.050458        1.191904
# 19  1.356662  1.360505  1.359462    1.384344      0.303734       -0.688350
# 20  1.838085  1.832970  1.839146    0.340895      0.230711       -1.106503
# 21  1.838085  1.832970  1.839146    0.340895      0.230711       -1.106503
# 22  0.958424  0.965483  0.949815   -0.775384     -0.805308       -0.168768
# 23 -1.256775 -1.260177 -1.254352    0.138385     -1.815573        0.872309

# %% [markdown]
# ## Step 3: Make sure to do the following:
#
# - Add a column to the DataFrame that consists of the tickers from the original DataFrame. (Hint: This column was the index).
#
# - Set the new column of tickers as the index for the new DataFrame.
#
# - Review the resulting DataFrame.

# %%
# Create a Ticker column in the df_stocks_scaled DataFrame
# using the index of the original df_stocks DataFrame("Ticker")
stocks_scaled["Ticker"] = df_stocks.index

# Set the newly created Ticker column as index of the df_stocks_scaled DataFrame
stocks_scaled = stocks_scaled.set_index(["Ticker"])

# Review the DataFrame
stocks_scaled.head()
# Out:
#         MeanOpen  MeanHigh   MeanLow  MeanVolume  AnnualReturn  AnnualVariance
# Ticker
# ARX    -0.916832 -0.917217 -0.918045   -0.152786     -1.332445        0.460854
# CCO    -0.880152 -0.879472 -0.879062   -0.379117      1.695742        0.559411
# CNQ     0.971524  0.977848  0.968315    1.272074     -0.089092       -0.154415
# CVE    -0.994122 -0.992707 -0.994689    2.376902     -0.010201        1.331607
# CPG    -1.218785 -1.221130 -1.218673    1.846798     -2.254365        1.424424

# %% [markdown]
# ## Step 4: Encode the “EnergyType” column using `pd.get_dummies`, and save the result in a separate DataFrame called `df_oil_dummies`. Note that, because the company name isn’t relevant for clustering, you don’t need to encode the “CompanyName” column.

# %%
# Encode (convert to dummy variables) the EnergyType column
df_oil_dummies = pd.get_dummies(df_stocks["EnergyType"])
oil_dummies = df_oil_dummies.astype(int)
# Review the DataFrame
oil_dummies
# Out:
#         Oil  Other Energy
# Ticker
# ARX       1             0
# CCO       0             1
# CNQ       1             0
# CVE       1             0
# CPG       0             1
# ENB       0             1
# ERF       1             0
# GEI       0             1
# HSE       0             1
# IMO       1             0
# IPL       0             1
# KEY       0             1
# MEG       0             1
# MTL       0             1
# PXT       1             0
# PKI       0             1
# PPL       1             0
# PSK       1             0
# VII       1             0
# SU        1             0
# TRP       0             1
# TOU       1             0
# VET       1             0
# WCP       1             0

# %% [markdown]
# ## Step 5: Using the `pd.concat` function, concatenate the `df_stocks_scaled` DataFrame with the `df_oil_dummies` DataFrame, along an axis value of 1 (`axis=1` tells Pandas to join the data horizontally by columns). Review the concatenated DataFrame.

# %%
# Concatenate the `EnergyType` encoded dummies with the scaled data DataFrame
df_stocks_scaled = pd.concat([stocks_scaled, oil_dummies], axis = 1)

# Display the sample data
df_stocks_scaled
# Out:
#         MeanOpen  MeanHigh   MeanLow  MeanVolume  AnnualReturn  \
# Ticker
# ARX    -0.916832 -0.917217 -0.918045   -0.152786     -1.332445
# CCO    -0.880152 -0.879472 -0.879062   -0.379117      1.695742
# CNQ     0.971524  0.977848  0.968315    1.272074     -0.089092
# CVE    -0.994122 -0.992707 -0.994689    2.376902     -0.010201
# CPG    -1.218785 -1.221130 -1.218673    1.846798     -2.254365
# ENB     1.067154  1.064401  1.063459    1.720226      0.389472
# ERF    -0.817272 -0.815696 -0.817615   -0.453229      0.206587
# GEI    -0.563789 -0.566448 -0.559934   -1.073401      0.950187
# HSE    -0.540209 -0.539766 -0.539452   -0.281932      0.094118
# IMO     0.826770  0.829470  0.829563   -0.483906      0.571378
# IPL    -0.246115 -0.252773 -0.243448   -0.432973     -0.034325
# KEY     0.464557  0.461781  0.464184   -0.920633     -0.237095
# MEG    -1.267255 -1.267335 -1.268227    0.387923      1.683028
# MTL    -0.806137 -0.809839 -0.803079   -1.265295     -0.029109
# PXT    -0.460954 -0.455816 -0.465451   -0.845754      0.304060
# PKI     0.478966  0.483257  0.482024   -1.034973      1.644887
# PPL     1.078289  1.074163  1.082620   -0.337238      0.593546
# PSK    -0.122976 -0.120665 -0.123858   -0.938063     -1.240188
# VII    -0.787142 -0.783807 -0.791847   -0.433758     -1.050458
# SU      1.356662  1.360505  1.359462    1.384344      0.303734
# TRP     1.838085  1.832970  1.839146    0.340895      0.230711
# TOU     1.838085  1.832970  1.839146    0.340895      0.230711
# VET     0.958424  0.965483  0.949815   -0.775384     -0.805308
# WCP    -1.256775 -1.260177 -1.254352    0.138385     -1.815573
#
#         AnnualVariance  Oil  Other Energy
# Ticker
# ARX           0.460854    1             0
# CCO           0.559411    0             1
# CNQ          -0.154415    1             0
# CVE           1.331607    1             0
# CPG           1.424424    0             1
# ENB          -0.736194    0             1
# ERF           0.533576    1             0
# GEI          -0.552474    0             1
# HSE           0.006339    0             1
# IMO          -0.855803    1             0
# IPL          -1.025169    0             1
# KEY          -0.790735    0             1
# MEG           2.769786    0             1
# MTL          -0.783080    0             1
# PXT           0.929721    1             0
# PKI          -0.508458    0             1
# PPL          -1.177312    1             0
# PSK          -0.426167    1             0
# VII           1.191904    1             0
# SU           -0.688350    1             0
# TRP          -1.106503    0             1
# TOU          -1.106503    1             0
# VET          -0.168768    1             0
# WCP           0.872309    1             0

# %% [markdown]
# ## Step 6: Using the concatenated DataFrame, cluster the data by using the K-means algorithm and a k value of 3. Create a copy of the concatenated DataFrame, and add the resulting list of company segment values as a new column.

# %%
# Initialize the K-Means model with n_clusters=3
model = KMeans(n_clusters = 3)

# %%
# Fit the model for the df_stocks_scaled DataFrame
model.fit(df_stocks_scaled)
# Out:
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
# Predict the model segments (clusters)
stock_clusters = model.predict(df_stocks_scaled)

# View the stock segments
stock_clusters
# Out:
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\ppate\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# array([2, 1, 0, 2, 2, 0, 1, 1, 1, 0, 1, 1, 2, 1, 1, 1, 0, 1, 2, 0, 0, 0,
#        0, 2])

# %%
# Create a copy of the concatenated DataFrame
df_stocks_scaled_predictions = stock_clusters.copy()

# %%
# Create a new column in the copy of the concatenated DataFrame with the predicted clusters
df_stocks_scaled_predictions["StockCluster"] = stock_clusters

# Review the DataFrame
df_stocks_scaled_predictions
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[96], line 2
#       1 # Create a new column in the copy of the concatenated DataFrame with the predicted clusters
# ----> 2 df_stocks_scaled_predictions["StockCluster"] = stock_clusters
#       4 # Review the DataFrame
#       5 df_stocks_scaled_predictions
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
